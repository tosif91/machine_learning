# %%
import html5lib
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.brainyquote.com/topics/motivational-quotes'
r = requests.get(url)
r.content

# %%
soup = BeautifulSoup(r.content,'html5lib')

# %%
table = soup.find('div',attrs={'id' : 'quotesList'})

# %%
for row in table.findAll('div',attrs={'class' : 'qti-listm'}):
    print(row.img['alt'].split('-'))

# %%
type(table)
# Out:
# bs4.element.Tag

# %%
q = requests.get('https://blog.hubspot.com/sales/famous-quotes')
q.content
# Out:
# b'<!doctype html><!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en-us" > <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en-us" >        <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en-us" >               <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en-us"><!--<![endif]--><head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n    <meta name="author" content="Meredith Hart">\n    <meta name="description" content="In need of inspiration? We\'ve compiled the 100 most famous quotes of all time to motivate you in your work and personal life. ">\n    <meta name="generator" content="HubSpot">\n    <meta class="swiftype" name="doc-type" data-type="string" content="Customer">\n    <meta class="swiftype" name="meta-description" data-type="text" content="In need of inspiration? We\'ve compiled the 100 most famous quotes of all time to motivate you in your work and personal l
# ...

# %%
soup = BeautifulSoup(q.content,'html5lib')

# %%
tab = soup.find('span',attrs={'id':'hs_cos_wrapper_post_body'})

# %%
l = tab.findAll('p')
type(l)

# %%
link = requests.get("https://www.linkedin.com/feed/")

# %%
link.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta name="pageKey" content="d_registration-cold-join"><meta name="locale" content="en_US"><meta id="config"data-app-id="com.linkedin.registration-frontend.d_web"data-custom-tracking-code=""data-tracking-page-type=""data-jet-tags=""data-multiproduct-name="registration-fe"data-service-name="registration-frontend"data-app-version=""data-enable-page-view-heartbeat-tracking/><link rel="canonical" href="https://www.linkedin.com/signup"><link rel="icon" href="https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca"><script>function getDfd() {let yFn,nFn;const p=new Promise((y, n)=>{yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}window.lazyloader = getDfd();window.tracking = getDfd();window.impressionTracking = getDfd();window.pemTracking = getDfd();window.ingraphTracking = getDfd();window.appDetection = getDfd();</script><title>Sign Up | LinkedIn</title><meta name="description" content="500 million+ members | Manage your professional identi
# ...
