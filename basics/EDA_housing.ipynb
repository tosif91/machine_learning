# %%
# METADATA LINK :  https://cdn.upgrad.com/UpGrad/temp/87f67e28-c47e-4725-ae3c-111142c7eaba/data_description.txt
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df=pd.read_csv('data/main_housing.csv')

# %%
df.head(3)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal       MoSold       YrSold      SalePrice
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
col_todrop = df.columns[   ((df.isnull().sum() / df.shape[0]) * 100  > 70).values ]
df.drop(columns=col_todrop,inplace=True)
print(col_todrop)
# Out:
# Index(['Alley', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df.LotFrontage =  df.LotFrontage.fillna(0)
df.MasVnrType.fillna('No Masonary',inplace=True)
df.MasVnrArea.fillna(0,inplace=True)
df.BsmtQual.fillna('No Basement',inplace=True)
df.BsmtExposure.fillna('No Basement',inplace=True)
df.BsmtCond.fillna('No Basement',inplace=True)
df.BsmtFinType1.fillna('No Basement',inplace=True)
df.BsmtFinType2.fillna('No Basement',inplace=True)
df.Electrical.dropna(inplace=True)
df.FireplaceQu.fillna('No FirePlace',inplace=True)
df.Fireplaces.fillna('No Fireplace',inplace=True)
df.GarageArea.fillna(0,inplace=True)
df.GarageCars.fillna(0,inplace=True)
df.GarageCond.fillna('Ng',inplace=True)
df.GarageType.fillna('Ng',inplace=True)
df.GarageFinish.fillna('Ng',inplace=True)
df.GarageYrBlt.fillna(0,inplace=True)
df.GarageQual .fillna('No Garage',inplace=True)
df.drop(columns=['Electrical','Id'],inplace=True)
df.columns=df.columns.str.lower()

# %%
df.shape
# Out:
# (1460, 75)

# %%
df.describe()
# Out:
#         mssubclass  lotfrontage        lotarea  overallqual  overallcond    yearbuilt  yearremodadd   masvnrarea   bsmtfinsf1   bsmtfinsf2    bsmtunfsf  totalbsmtsf     1stflrsf     2ndflrsf  lowqualfinsf    grlivarea  bsmtfullbath  bsmthalfbath     fullbath     halfbath  bedroomabvgr  kitchenabvgr  totrmsabvgrd   fireplaces  garageyrblt   garagecars   garagearea   wooddecksf  openporchsf  enclosedporch    3ssnporch  screenporch     poolarea       miscval       mosold       yrsold      saleprice
# ...

# %%
df.head()
# Out:
#    mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
df.street.hist()
# Out:
# <AxesSubplot:>

# %%
df.mszoning.hist()
# Out:
# <AxesSubplot:>

# %%
df.mssubclass.hist()
# Out:
# <AxesSubplot:>

# %%
df.lotshape.hist()
# Out:
# <AxesSubplot:>

# %%
df.landcontour.hist()
# Out:
# <AxesSubplot:>

# %%
df.groupby(['mszoning']).get_group('FV')
# Out:
#       mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd   masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
df.groupby(['lotshape']).get_group('Reg')
# Out:
#       mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
df.groupby(['lotshape']).get_group('IR3')
# Out:
#       mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
df.groupby(['neighborhood']).get_group('Blmngtn')
# Out:
#       mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
df.head()
# Out:
#    mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
df.mszoning.unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
df.saleprice.hist()
# Out:
# <AxesSubplot:>

# %%
df.lotarea.hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='yrsold',y='saleprice',data=df)
# Out:
# <AxesSubplot:xlabel='yrsold', ylabel='saleprice'>

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='neighborhood',y='saleprice',data=df)
# Out:
# <AxesSubplot:xlabel='neighborhood', ylabel='saleprice'>

# %%
df.neighborhood.unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
df.groupby('neighborhood').get_group('NPkVill')
# Out:
#       mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
df.head()
# Out:
#    mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='garagearea',y='lotfrontage',data=df)
# Out:
# <AxesSubplot:xlabel='garagearea', ylabel='lotfrontage'>

# %%
df.garagearea.unique()
# Out:
# array([ 548,  460,  608,  642,  836,  480,  636,  484,  468,  205,  384,
#         736,  352,  840,  576,  516,  294,  853,  280,  534,  572,  270,
#         890,  772,  319,  240,  250,  271,  447,  556,  691,  672,  498,
#         246,    0,  440,  308,  504,  300,  670,  826,  386,  388,  528,
#         894,  565,  641,  288,  645,  852,  558,  220,  667,  360,  427,
#         490,  379,  297,  283,  509,  405,  758,  461,  400,  462,  420,
#         432,  506,  684,  472,  366,  476,  410,  740,  648,  273,  546,
#         325,  792,  450,  180,  430,  594,  390,  540,  264,  530,  435,
#         453,  750,  487,  624,  471,  318,  766,  660,  470,  720,  577,
#         380,  434,  866,  495,  564,  312,  625,  680,  678,  726,  532,
#         216,  303,  789,  511,  616,  521,  451, 1166,  252,  497,  682,
#         666,  786,  795,  856,  473,  398,  500,  349,  454,  644,  299,
#         210,  431,  438,  675,  968,  721,  336,  810,  494,  457,  818,
# ...

# %%
df.garagetype.unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'Ng', 'Basment',
#        '2Types'], dtype=object)

# %%
df.groupby('garagetype').get_group('Ng')
# Out:
#       mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation     bsmtqual     bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
sns.scatterplot('garageyrblt',y='garagequal',data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='garageyrblt', ylabel='garagequal'>

# %%
df.groupby('garagetype').get_group('Ng')
# Out:
#       mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation     bsmtqual     bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='housestyle',y='yearbuilt',data=df)
# Out:
# <AxesSubplot:xlabel='housestyle', ylabel='yearbuilt'>

# %%
df.head()
# Out:
#    mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice
# ...

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='saleprice',y='yrsold',data=df)
# Out:
# <AxesSubplot:xlabel='saleprice', ylabel='yrsold'>

# %%
df['f_m'] = (df['1stflrsf']+df['2ndflrsf'] )/2

# %%
df.head()
# Out:
#    mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice     f_m
# ...

# %%
df.f_m.hist()
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='saleprice',y='f_m',data=df)
# Out:
# <AxesSubplot:xlabel='saleprice', ylabel='f_m'>

# %%
df.head()
# Out:
#    mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice     f_m
# ...

# %%
df.salecondition.unique
# Out:
# <bound method Series.unique of 0        Normal
# 1        Normal
# 2        Normal
# 3       Abnorml
# 4        Normal
#          ...
# 1455     Normal
# 1456     Normal
# 1457     Normal
# 1458     Normal
# 1459     Normal
# Name: salecondition, Length: 1460, dtype: object>

# %%
df.groupby('salecondition').get_group('Family')
# Out:
#       mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice     f_m
# ...

# %%
df.heating.unique
# Out:
# <bound method Series.unique of 0       GasA
# 1       GasA
# 2       GasA
# 3       GasA
# 4       GasA
#         ...
# 1455    GasA
# 1456    GasA
# 1457    GasA
# 1458    GasA
# 1459    GasA
# Name: heating, Length: 1460, dtype: object>

# %%
df.groupby('heating').get_group('Wall')
# Out:
#       mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation     bsmtqual     bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice    f_m
# ...

# %%
df.head()
# Out:
#    mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice     f_m
# ...

# %%
df.yearbuilt
# Out:
# 0       2003
# 1       1976
# 2       2001
# 3       1915
# 4       2000
#         ...
# 1455    1999
# 1456    1978
# 1457    1941
# 1458    1950
# 1459    1965
# Name: yearbuilt, Length: 1460, dtype: int64

# %%
df.head()
# Out:
#    mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  yearremodadd roofstyle roofmatl exterior1st exterior2nd masvnrtype  masvnrarea exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1  bsmtfinsf1 bsmtfintype2  bsmtfinsf2  bsmtunfsf  totalbsmtsf heating heatingqc centralair  1stflrsf  2ndflrsf  lowqualfinsf  grlivarea  bsmtfullbath  bsmthalfbath  fullbath  halfbath  bedroomabvgr  kitchenabvgr kitchenqual  totrmsabvgrd functional  fireplaces   fireplacequ garagetype  garageyrblt garagefinish  garagecars  garagearea garagequal garagecond paveddrive  wooddecksf  openporchsf  enclosedporch  3ssnporch  screenporch  poolarea  miscval  mosold  yrsold saletype salecondition  saleprice     f_m
# ...

# %%
plt.figure(figsize=(20,10))
sns.stripplot(y=df['saleprice'])
# Out:
# <AxesSubplot:ylabel='saleprice'>

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x=df['saleprice'])
# Out:
# <AxesSubplot:xlabel='saleprice'>

# %%
plt.figure(figsize=(10,5))
sns.stripplot(x='yrsold',y='saleprice',data=df)
# Out:
# <AxesSubplot:xlabel='yrsold', ylabel='saleprice'>

# %%
plt.figure(figsize=(20,10))
sns.swarmplot(x="saleprice",data=df)
# Out:
# <AxesSubplot:xlabel='saleprice'>

# %%
sns.swarmplot(x='yrsold',y='saleprice',data=df)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 54.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 54.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 53.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df['saleprice'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['yrsold'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>
